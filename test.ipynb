# %%
import pandas as pd

# %%
url = 'https://data.epa.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=CSV'

# %%
df = pd.read_csv(url)
df
# Out:
#    site county  pm25  datacreationdate itemunit
# 0    大城    彰化縣    18  2022-09-21 19:00    μg/m3
# 1   富貴角    新北市    13  2022-09-21 19:00    μg/m3
# 2    麥寮    雲林縣    10  2022-09-21 19:00    μg/m3
# 3    關山    臺東縣     9  2022-09-21 19:00    μg/m3
# 4    馬公    澎湖縣    10  2022-09-21 19:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 73   土城    新北市     2  2022-09-21 19:00    μg/m3
# 74   新店    新北市     9  2022-09-21 19:00    μg/m3
# 75   萬里    新北市    14  2022-09-21 19:00    μg/m3
# 76   汐止    新北市     5  2022-09-21 19:00    μg/m3
# 77   基隆    基隆市    10  2022-09-21 19:00    μg/m3
#
# [78 rows x 5 columns]
